# %%
import csv
from statistics import mean


def read_csv():
    with open('./world_population.csv') as csvfile:
        reader = csv.reader(csvfile, delimiter=',')
        header = next(reader)
        data = []
        for row in reader:
            iterable = zip(header, row)
            data.append({key: value for key, value in iterable})
    return data


def point1(data):
    lista = [i for i in data]
    return lista


def point2(data):
    lista = [{'Rank': i['Rank'], 'CCA3': i['CCA3'],
              'Country/Territory': i['Country/Territory'], 'Capital': i['Capital'],
              'Continent': i['Continent'], 'Population': [i['2022 Population'],
                                                          i['2020 Population'], i['2015 Population'],
                                                          i['2010 Population'], i['2000 Population'],
                                                          i['1990 Population'], i['1980 Population'],
                                                          i['1970 Population']], 'Area (km²)': i['Area (kmÂ²)'],
              'Density (per km²)': i['Density (per kmÂ²)'], 'Growth Rate': i['Growth Rate'],
              'World Population Percentage': i['World Population Percentage']} for i in data]
    return lista


def point3(data):
    lista = [{'Country/Territory': i['Country/Territory'],
              '2022 Population':int(i['2022 Population'])} for i in data]
    return lista


def point4(data):
    lista = [(i['CCA3'], float(i['World Population Percentage']))
             for i in data if float(i['World Population Percentage']) >= 1.0]
    return lista


def point5(data):
    lista = [(i['CCA3'], mean([int(i['2022 Population']), int(i['2020 Population']), int(i['2015 Population']), int(i['2010 Population']), int(
        i['2000 Population']), int(i['1990 Population']), int(i['1980 Population']), int(i['1970 Population'])])) for i in data]
    return lista


def point6(data):
    conjunto = {(i['Country/Territory'], i['Continent']) for i in data}
    return conjunto


def point7(data):
    conjunto = {i['Continent'] for i in data}
    return conjunto


def point8(data):
    conjunto = {(i['Country/Territory'], i['Continent'])
                for i in data if i['Continent'] == 'North America'}
    return conjunto


def point9(data):
    conjunto = {(i['Country/Territory'], i['Continent'])
                for i in data if i['Continent'] == 'South America'}
    return conjunto


def point10(data):
    conjunto = {(i['Country/Territory'], i['Continent'])
                for i in data if i['Continent'] == 'Oceania'}
    return conjunto


def point11(data):
    conjunto = {(i['Country/Territory'], i['Continent'])
                for i in data if i['Continent'] == 'Europe'}
    return conjunto


def point12(data):
    conjunto = {(i['Country/Territory'], i['Continent'])
                for i in data if i['Continent'] == 'Asia'}
    return conjunto


def point13(data):
    conjunto = {(i['Country/Territory'], i['Continent'])
                for i in data if i['Continent'] == 'Africa'}
    return conjunto


def point14(data):
    Europa = point11(data)
    Asia = point12(data)
    Africa = point13(data)
    union = (Europa.union(Asia)).union(Africa)
    return union


def point15(data):
    NorteA = point8(data)
    SurA = point9(data)
    union = NorteA.union(SurA)
    return union


def point16(data):
    conjunto = {(i['Country/Territory'], float(i['World Population Percentage']))
                for i in data if float(i['World Population Percentage']) < 0.4}
    return conjunto


def point17(data):
    conjunto = {(i['Country/Territory'], float(i['World Population Percentage']))
                for i in data if float(i['World Population Percentage']) > 0.2}
    return conjunto


def point18(data):
    Conjunto1 = point16(data)
    Conjunto2 = point17(data)
    union = Conjunto1.union(Conjunto2)
    return union


def point19(data):
    Conjunto1 = point16(data)
    Conjunto2 = point17(data)
    diferencia = Conjunto1.difference(Conjunto2)
    return diferencia


def point20(data):
    Conjunto1 = point16(data)
    Conjunto2 = point17(data)
    diferencia = Conjunto2.difference(Conjunto1)
    return diferencia


if __name__ == '__main__':
    datos = read_csv()

# %%
print(point1(datos))
# Out:
# [{'Rank': '36', 'CCA3': 'AFG', 'Country/Territory': 'Afghanistan', 'Capital': 'Kabul', 'Continent': 'Asia', '2022 Population': '41128771', '2020 Population': '38972230', '2015 Population': '33753499', '2010 Population': '28189672', '2000 Population': '19542982', '1990 Population': '10694796', '1980 Population': '12486631', '1970 Population': '10752971', 'Area (kmÂ²)': '652230', 'Density (per kmÂ²)': '63.0587', 'Growth Rate': '1.0257', 'World Population Percentage': '0.52'}, {'Rank': '138', 'CCA3': 'ALB', 'Country/Territory': 'Albania', 'Capital': 'Tirana', 'Continent': 'Europe', '2022 Population': '2842321', '2020 Population': '2866849', '2015 Population': '2882481', '2010 Population': '2913399', '2000 Population': '3182021', '1990 Population': '3295066', '1980 Population': '2941651', '1970 Population': '2324731', 'Area (kmÂ²)': '28748', 'Density (per kmÂ²)': '98.8702', 'Growth Rate': '0.9957', 'World Population Percentage': '0.04'}, {'Rank': '34', 'CCA3': 'DZA', 'Country/Territory':
# ...

# %%
print(point2(datos))
# Out:
# [{'Rank': '36', 'CCA3': 'AFG', 'Country/Territory': 'Afghanistan', 'Capital': 'Kabul', 'Continent': 'Asia', 'Population': ['41128771', '38972230', '33753499', '28189672', '19542982', '10694796', '12486631', '10752971'], 'Area (km²)': '652230', 'Density (per km²)': '63.0587', 'Growth Rate': '1.0257', 'World Population Percentage': '0.52'}, {'Rank': '138', 'CCA3': 'ALB', 'Country/Territory': 'Albania', 'Capital': 'Tirana', 'Continent': 'Europe', 'Population': ['2842321', '2866849', '2882481', '2913399', '3182021', '3295066', '2941651', '2324731'], 'Area (km²)': '28748', 'Density (per km²)': '98.8702', 'Growth Rate': '0.9957', 'World Population Percentage': '0.04'}, {'Rank': '34', 'CCA3': 'DZA', 'Country/Territory': 'Algeria', 'Capital': 'Algiers', 'Continent': 'Africa', 'Population': ['44903225', '43451666', '39543154', '35856344', '30774621', '25518074', '18739378', '13795915'], 'Area (km²)': '2381741', 'Density (per km²)': '18.8531', 'Growth Rate': '1.0164', 'World Population Percent
# ...

# %%
print(point3(datos))
# Out:
# [{'Country/Territory': 'Afghanistan', '2022 Population': 41128771}, {'Country/Territory': 'Albania', '2022 Population': 2842321}, {'Country/Territory': 'Algeria', '2022 Population': 44903225}, {'Country/Territory': 'American Samoa', '2022 Population': 44273}, {'Country/Territory': 'Andorra', '2022 Population': 79824}, {'Country/Territory': 'Angola', '2022 Population': 35588987}, {'Country/Territory': 'Anguilla', '2022 Population': 15857}, {'Country/Territory': 'Antigua and Barbuda', '2022 Population': 93763}, {'Country/Territory': 'Argentina', '2022 Population': 45510318}, {'Country/Territory': 'Armenia', '2022 Population': 2780469}, {'Country/Territory': 'Aruba', '2022 Population': 106445}, {'Country/Territory': 'Australia', '2022 Population': 26177413}, {'Country/Territory': 'Austria', '2022 Population': 8939617}, {'Country/Territory': 'Azerbaijan', '2022 Population': 10358074}, {'Country/Territory': 'Bahamas', '2022 Population': 409984}, {'Country/Territory': 'Bahrain', '2022 Popu
# ...

# %%
print(point4(datos))
# Out:
# [('BGD', 2.15), ('BRA', 2.7), ('CHN', 17.88), ('COD', 1.24), ('EGY', 1.39), ('ETH', 1.55), ('DEU', 1.05), ('IND', 17.77), ('IDN', 3.45), ('IRN', 1.11), ('JPN', 1.55), ('MEX', 1.6), ('NGA', 2.74), ('PAK', 2.96), ('PHL', 1.45), ('RUS', 1.81), ('TUR', 1.07), ('USA', 4.24), ('VNM', 1.23)]

# %%
print(point5(datos))
# Out:
# [('AFG', 24440194), ('ALB', 2906064.875), ('DZA', 31572797.125), ('ASM', 45336), ('AND', 59490.75), ('AGO', 20386478.125), ('AIA', 11418.125), ('ATG', 78731.25), ('ARG', 37059946.875), ('ARM', 2975690.875), ('ABW', 86726.75), ('AUS', 20131773.75), ('AUT', 8194332.875), ('AZE', 8396282.125), ('BHS', 322624.75), ('BHR', 917437.375), ('BGD', 129080133.125), ('BRB', 266702.375), ('BLR', 9784222.625), ('BEL', 10628270.25), ('BLZ', 271400.375), ('BEN', 8170413), ('BMU', 59903.875), ('BTN', 607943.875), ('BOL', 8935532.25), ('BIH', 3822048.25), ('BWA', 1771601.75), ('BRA', 171911240.375), ('VGB', 21943.5), ('BRN', 328166.875), ('BGR', 7886459.875), ('BFA', 14073766.75), ('BDI', 8070709.5), ('KHM', 12110361.25), ('CMR', 17348887.125), ('CAN', 31290646.75), ('CPV', 459559.625), ('CYM', 43040), ('CAF', 3931573.375), ('TCD', 10320605.875), ('CHL', 15470413.75), ('CHN', 1226929271.375), ('COL', 39204812.375), ('COM', 570967), ('COK', 17511), ('CRI', 3903609.25), ('HRV', 4418205.75), ('CUB', 1069
# ...

# %%
print(point6(datos))
# Out:
# {('Malta', 'Europe'), ('Sint Maarten', 'North America'), ('Saint Pierre and Miquelon', 'North America'), ('Northern Mariana Islands', 'Oceania'), ('Namibia', 'Africa'), ('Uzbekistan', 'Asia'), ('Jamaica', 'North America'), ('Venezuela', 'South America'), ('Belarus', 'Europe'), ('Bosnia and Herzegovina', 'Europe'), ('Lebanon', 'Asia'), ('Fiji', 'Oceania'), ('Guyana', 'South America'), ('Slovenia', 'Europe'), ('Serbia', 'Europe'), ('Seychelles', 'Africa'), ('Russia', 'Europe'), ('Croatia', 'Europe'), ('Djibouti', 'Africa'), ('Cameroon', 'Africa'), ('Central African Republic', 'Africa'), ('Switzerland', 'Europe'), ('Liberia', 'Africa'), ('Martinique', 'North America'), ('French Polynesia', 'Oceania'), ('Dominican Republic', 'North America'), ('Estonia', 'Europe'), ('Bahamas', 'North America'), ('Netherlands', 'Europe'), ('South Korea', 'Asia'), ('Mozambique', 'Africa'), ('Armenia', 'Asia'), ('Falkland Islands', 'South America'), ('Luxembourg', 'Europe'), ('New Caledonia', 'Oceania'), ('
# ...

# %%
print(point7(datos))
# Out:
# {'South America', 'Africa', 'Asia', 'Oceania', 'Europe', 'North America'}

# %%
print(point8(datos))
# Out:
# {('Cuba', 'North America'), ('Sint Maarten', 'North America'), ('Aruba', 'North America'), ('Antigua and Barbuda', 'North America'), ('Honduras', 'North America'), ('Saint Pierre and Miquelon', 'North America'), ('Curacao', 'North America'), ('Grenada', 'North America'), ('United States Virgin Islands', 'North America'), ('Jamaica', 'North America'), ('Puerto Rico', 'North America'), ('Saint Kitts and Nevis', 'North America'), ('British Virgin Islands', 'North America'), ('Guadeloupe', 'North America'), ('El Salvador', 'North America'), ('Montserrat', 'North America'), ('Saint Vincent and the Grenadines', 'North America'), ('Nicaragua', 'North America'), ('Anguilla', 'North America'), ('Haiti', 'North America'), ('Martinique', 'North America'), ('Dominican Republic', 'North America'), ('Bahamas', 'North America'), ('Cayman Islands', 'North America'), ('United States', 'North America'), ('Canada', 'North America'), ('Barbados', 'North America'), ('Bermuda', 'North America'), ('Saint B
# ...

# %%
print(point9(datos))
# Out:
# {('Colombia', 'South America'), ('Uruguay', 'South America'), ('Peru', 'South America'), ('Argentina', 'South America'), ('Brazil', 'South America'), ('Suriname', 'South America'), ('Falkland Islands', 'South America'), ('Paraguay', 'South America'), ('Venezuela', 'South America'), ('Bolivia', 'South America'), ('French Guiana', 'South America'), ('Guyana', 'South America'), ('Ecuador', 'South America'), ('Chile', 'South America')}

# %%
print(point10(datos))
# Out:
# {('Australia', 'Oceania'), ('Niue', 'Oceania'), ('Northern Mariana Islands', 'Oceania'), ('Tokelau', 'Oceania'), ('Solomon Islands', 'Oceania'), ('Tuvalu', 'Oceania'), ('Fiji', 'Oceania'), ('Guam', 'Oceania'), ('Nauru', 'Oceania'), ('Palau', 'Oceania'), ('New Zealand', 'Oceania'), ('Cook Islands', 'Oceania'), ('Papua New Guinea', 'Oceania'), ('French Polynesia', 'Oceania'), ('Samoa', 'Oceania'), ('New Caledonia', 'Oceania'), ('Wallis and Futuna', 'Oceania'), ('American Samoa', 'Oceania'), ('Kiribati', 'Oceania'), ('Marshall Islands', 'Oceania'), ('Tonga', 'Oceania'), ('Micronesia', 'Oceania'), ('Vanuatu', 'Oceania')}

# %%
print(point11(datos))
# Out:
# {('Austria', 'Europe'), ('Malta', 'Europe'), ('Sweden', 'Europe'), ('Moldova', 'Europe'), ('Norway', 'Europe'), ('Monaco', 'Europe'), ('Vatican City', 'Europe'), ('Belarus', 'Europe'), ('Bosnia and Herzegovina', 'Europe'), ('Czech Republic', 'Europe'), ('Slovenia', 'Europe'), ('United Kingdom', 'Europe'), ('Serbia', 'Europe'), ('North Macedonia', 'Europe'), ('Russia', 'Europe'), ('Belgium', 'Europe'), ('Croatia', 'Europe'), ('Ireland', 'Europe'), ('Slovakia', 'Europe'), ('Switzerland', 'Europe'), ('Montenegro', 'Europe'), ('Finland', 'Europe'), ('Latvia', 'Europe'), ('Estonia', 'Europe'), ('Netherlands', 'Europe'), ('Lithuania', 'Europe'), ('San Marino', 'Europe'), ('Germany', 'Europe'), ('Luxembourg', 'Europe'), ('Hungary', 'Europe'), ('France', 'Europe'), ('Spain', 'Europe'), ('Bulgaria', 'Europe'), ('Portugal', 'Europe'), ('Romania', 'Europe'), ('Iceland', 'Europe'), ('Poland', 'Europe'), ('Albania', 'Europe'), ('Cyprus', 'Europe'), ('Denmark', 'Europe'), ('Liechtenstein', 'Europe
# ...

# %%
print(point12(datos))
# Out:
# {('Pakistan', 'Asia'), ('Turkey', 'Asia'), ('Uzbekistan', 'Asia'), ('Myanmar', 'Asia'), ('Kazakhstan', 'Asia'), ('Afghanistan', 'Asia'), ('Lebanon', 'Asia'), ('Kuwait', 'Asia'), ('Saudi Arabia', 'Asia'), ('Philippines', 'Asia'), ('Singapore', 'Asia'), ('Bangladesh', 'Asia'), ('Vietnam', 'Asia'), ('Maldives', 'Asia'), ('Malaysia', 'Asia'), ('Thailand', 'Asia'), ('Laos', 'Asia'), ('Palestine', 'Asia'), ('Turkmenistan', 'Asia'), ('Bhutan', 'Asia'), ('Japan', 'Asia'), ('Macau', 'Asia'), ('Sri Lanka', 'Asia'), ('Jordan', 'Asia'), ('Kyrgyzstan', 'Asia'), ('North Korea', 'Asia'), ('Tajikistan', 'Asia'), ('Bahrain', 'Asia'), ('Hong Kong', 'Asia'), ('Indonesia', 'Asia'), ('Israel', 'Asia'), ('United Arab Emirates', 'Asia'), ('Yemen', 'Asia'), ('Oman', 'Asia'), ('South Korea', 'Asia'), ('Georgia', 'Asia'), ('Syria', 'Asia'), ('Armenia', 'Asia'), ('Nepal', 'Asia'), ('Qatar', 'Asia'), ('Iraq', 'Asia'), ('Taiwan', 'Asia'), ('Iran', 'Asia'), ('Mongolia', 'Asia'), ('India', 'Asia'), ('Timor-Leste',
# ...

# %%
print(point13(datos))
# Out:
# {('Libya', 'Africa'), ('Eswatini', 'Africa'), ('Mauritania', 'Africa'), ('Namibia', 'Africa'), ('Mauritius', 'Africa'), ('Guinea-Bissau', 'Africa'), ('Ivory Coast', 'Africa'), ('Guinea', 'Africa'), ('Lesotho', 'Africa'), ('Tunisia', 'Africa'), ('Chad', 'Africa'), ('Kenya', 'Africa'), ('Cape Verde', 'Africa'), ('Zambia', 'Africa'), ('Seychelles', 'Africa'), ('Rwanda', 'Africa'), ('Uganda', 'Africa'), ('Djibouti', 'Africa'), ('Sao Tome and Principe', 'Africa'), ('Benin', 'Africa'), ('Cameroon', 'Africa'), ('Eritrea', 'Africa'), ('Central African Republic', 'Africa'), ('Mali', 'Africa'), ('Republic of the Congo', 'Africa'), ('Sudan', 'Africa'), ('Togo', 'Africa'), ('Burundi', 'Africa'), ('Liberia', 'Africa'), ('Mayotte', 'Africa'), ('Sierra Leone', 'Africa'), ('Equatorial Guinea', 'Africa'), ('Burkina Faso', 'Africa'), ('Botswana', 'Africa'), ('Morocco', 'Africa'), ('Mozambique', 'Africa'), ('Algeria', 'Africa'), ('DR Congo', 'Africa'), ('Western Sahara', 'Africa'), ('Egypt', 'Africa'),
# ...

# %%
print(point14(datos))
# Out:
# {('Malta', 'Europe'), ('Uzbekistan', 'Asia'), ('Namibia', 'Africa'), ('Belarus', 'Europe'), ('Bosnia and Herzegovina', 'Europe'), ('Lebanon', 'Asia'), ('Slovenia', 'Europe'), ('Serbia', 'Europe'), ('Seychelles', 'Africa'), ('Russia', 'Europe'), ('Croatia', 'Europe'), ('Djibouti', 'Africa'), ('Cameroon', 'Africa'), ('Central African Republic', 'Africa'), ('Switzerland', 'Europe'), ('Liberia', 'Africa'), ('Estonia', 'Europe'), ('Netherlands', 'Europe'), ('South Korea', 'Asia'), ('Mozambique', 'Africa'), ('Armenia', 'Asia'), ('Luxembourg', 'Europe'), ('Hungary', 'Europe'), ('Egypt', 'Africa'), ('Gabon', 'Africa'), ('Romania', 'Europe'), ('Iran', 'Asia'), ('India', 'Asia'), ('Andorra', 'Europe'), ('Guernsey', 'Europe'), ('Faroe Islands', 'Europe'), ('China', 'Asia'), ('Ukraine', 'Europe'), ('Libya', 'Africa'), ('Eswatini', 'Africa'), ('Norway', 'Europe'), ('Mauritania', 'Africa'), ('Mauritius', 'Africa'), ('Kazakhstan', 'Asia'), ('Guinea-Bissau', 'Africa'), ('Saudi Arabia', 'Asia'), ('Vi
# ...

# %%
print(point15(datos))
# Out:
# {('Cuba', 'North America'), ('Sint Maarten', 'North America'), ('Aruba', 'North America'), ('Antigua and Barbuda', 'North America'), ('Honduras', 'North America'), ('Peru', 'South America'), ('Saint Pierre and Miquelon', 'North America'), ('Brazil', 'South America'), ('Curacao', 'North America'), ('Grenada', 'North America'), ('United States Virgin Islands', 'North America'), ('Jamaica', 'North America'), ('Venezuela', 'South America'), ('Puerto Rico', 'North America'), ('Saint Kitts and Nevis', 'North America'), ('Guyana', 'South America'), ('Uruguay', 'South America'), ('British Virgin Islands', 'North America'), ('Guadeloupe', 'North America'), ('El Salvador', 'North America'), ('Montserrat', 'North America'), ('Saint Vincent and the Grenadines', 'North America'), ('Suriname', 'South America'), ('Nicaragua', 'North America'), ('French Guiana', 'South America'), ('Anguilla', 'North America'), ('Haiti', 'North America'), ('Martinique', 'North America'), ('Dominican Republic', 'North
# ...

# %%
print(point16(datos))
# Out:
# {('Curacao', 0.0), ('Uruguay', 0.04), ('Sweden', 0.13), ('Comoros', 0.01), ('Mongolia', 0.04), ('Reunion', 0.01), ('Belgium', 0.15), ('Marshall Islands', 0.0), ('Saint Kitts and Nevis', 0.0), ('Rwanda', 0.17), ('Vanuatu', 0.0), ('Czech Republic', 0.13), ('Guatemala', 0.22), ('Belize', 0.01), ('Sao Tome and Principe', 0.0), ('Seychelles', 0.0), ('Cuba', 0.14), ('Tunisia', 0.15), ('Jordan', 0.14), ('Tokelau', 0.0), ('Australia', 0.33), ('Mayotte', 0.0), ('Zimbabwe', 0.2), ('Anguilla', 0.0), ('Liechtenstein', 0.0), ('Kyrgyzstan', 0.08), ('North Macedonia', 0.03), ('Tajikistan', 0.12), ('Gibraltar', 0.0), ('Haiti', 0.15), ('Cook Islands', 0.0), ('United Arab Emirates', 0.12), ('Falkland Islands', 0.0), ('Bermuda', 0.0), ('Dominica', 0.0), ('Trinidad and Tobago', 0.02), ('French Polynesia', 0.0), ('Austria', 0.11), ('Norway', 0.07), ('Croatia', 0.05), ('New Zealand', 0.07), ('Syria', 0.28), ('Jamaica', 0.04), ('Solomon Islands', 0.01), ('Qatar', 0.03), ('New Caledonia', 0.0), ('Hong Kong'
# ...

# %%
print(point17(datos))
# Out:
# {('Yemen', 0.42), ('North Korea', 0.33), ('Philippines', 1.45), ('Kenya', 0.68), ('Burkina Faso', 0.28), ('Cameroon', 0.35), ('Uganda', 0.59), ('Brazil', 2.7), ('Sudan', 0.59), ('Ecuador', 0.23), ('Guatemala', 0.22), ('Zambia', 0.25), ('Madagascar', 0.37), ('Senegal', 0.22), ('India', 17.77), ('Romania', 0.25), ('Bangladesh', 2.15), ('Somalia', 0.22), ('Saudi Arabia', 0.46), ('Germany', 1.05), ('Angola', 0.45), ('Australia', 0.33), ('DR Congo', 1.24), ('Poland', 0.5), ('South Korea', 0.65), ('Nigeria', 2.74), ('Pakistan', 2.96), ('Mexico', 1.6), ('Netherlands', 0.22), ('Afghanistan', 0.52), ('Ukraine', 0.5), ('Chad', 0.22), ('Turkey', 1.07), ('United Kingdom', 0.85), ('United States', 4.24), ('Iraq', 0.56), ('Malawi', 0.26), ('Mozambique', 0.41), ('Egypt', 1.39), ('Cambodia', 0.21), ('France', 0.81), ('Myanmar', 0.68), ('Italy', 0.74), ('China', 17.88), ('South Africa', 0.75), ('Ghana', 0.42), ('Nepal', 0.38), ('Uzbekistan', 0.43), ('Vietnam', 1.23), ('Argentina', 0.57), ('Malaysia',
# ...

# %%
print(point18(datos))
# Out:
# {('Yemen', 0.42), ('Curacao', 0.0), ('Uruguay', 0.04), ('Philippines', 1.45), ('Sweden', 0.13), ('Comoros', 0.01), ('Mongolia', 0.04), ('Reunion', 0.01), ('Belgium', 0.15), ('Marshall Islands', 0.0), ('Uganda', 0.59), ('Saint Kitts and Nevis', 0.0), ('Rwanda', 0.17), ('Vanuatu', 0.0), ('Czech Republic', 0.13), ('Guatemala', 0.22), ('Belize', 0.01), ('Sao Tome and Principe', 0.0), ('Seychelles', 0.0), ('Bangladesh', 2.15), ('Cuba', 0.14), ('Tunisia', 0.15), ('Jordan', 0.14), ('Tokelau', 0.0), ('Australia', 0.33), ('Mayotte', 0.0), ('Zimbabwe', 0.2), ('Anguilla', 0.0), ('Nigeria', 2.74), ('Liechtenstein', 0.0), ('Kyrgyzstan', 0.08), ('North Macedonia', 0.03), ('Tajikistan', 0.12), ('Gibraltar', 0.0), ('Turkey', 1.07), ('United States', 4.24), ('Uzbekistan', 0.43), ('Haiti', 0.15), ('Cook Islands', 0.0), ('United Arab Emirates', 0.12), ('Falkland Islands', 0.0), ('Bermuda', 0.0), ('Argentina', 0.57), ('Dominica', 0.0), ('Trinidad and Tobago', 0.02), ('French Polynesia', 0.0), ('Austria'
# ...

# %%
print(point19(datos))
# Out:
# {('Curacao', 0.0), ('Uruguay', 0.04), ('Sweden', 0.13), ('Comoros', 0.01), ('Mongolia', 0.04), ('Reunion', 0.01), ('Belgium', 0.15), ('Marshall Islands', 0.0), ('Saint Kitts and Nevis', 0.0), ('Rwanda', 0.17), ('Vanuatu', 0.0), ('Czech Republic', 0.13), ('Seychelles', 0.0), ('Belize', 0.01), ('Sao Tome and Principe', 0.0), ('Cuba', 0.14), ('Tunisia', 0.15), ('Jordan', 0.14), ('Tokelau', 0.0), ('Mayotte', 0.0), ('Zimbabwe', 0.2), ('Anguilla', 0.0), ('Liechtenstein', 0.0), ('Kyrgyzstan', 0.08), ('North Macedonia', 0.03), ('Tajikistan', 0.12), ('Gibraltar', 0.0), ('Haiti', 0.15), ('Cook Islands', 0.0), ('United Arab Emirates', 0.12), ('Falkland Islands', 0.0), ('Bermuda', 0.0), ('Dominica', 0.0), ('Trinidad and Tobago', 0.02), ('French Polynesia', 0.0), ('Austria', 0.11), ('Norway', 0.07), ('Croatia', 0.05), ('New Zealand', 0.07), ('Jamaica', 0.04), ('Solomon Islands', 0.01), ('Qatar', 0.03), ('New Caledonia', 0.0), ('Hong Kong', 0.09), ('Bahamas', 0.01), ('Western Sahara', 0.01), ('Gui
# ...

# %%
print(point20(datos))
# Out:
# {('Yemen', 0.42), ('Philippines', 1.45), ('Kenya', 0.68), ('Uganda', 0.59), ('Brazil', 2.7), ('Sudan', 0.59), ('India', 17.77), ('Bangladesh', 2.15), ('Saudi Arabia', 0.46), ('Germany', 1.05), ('Angola', 0.45), ('DR Congo', 1.24), ('Poland', 0.5), ('South Korea', 0.65), ('Nigeria', 2.74), ('Pakistan', 2.96), ('Mexico', 1.6), ('Afghanistan', 0.52), ('Ukraine', 0.5), ('Turkey', 1.07), ('United Kingdom', 0.85), ('Uzbekistan', 0.43), ('United States', 4.24), ('Iraq', 0.56), ('Mozambique', 0.41), ('Egypt', 1.39), ('France', 0.81), ('Myanmar', 0.68), ('Italy', 0.74), ('China', 17.88), ('South Africa', 0.75), ('Ghana', 0.42), ('Vietnam', 1.23), ('Argentina', 0.57), ('Malaysia', 0.43), ('Iran', 1.11), ('Tanzania', 0.82), ('Indonesia', 3.45), ('Morocco', 0.47), ('Canada', 0.48), ('Peru', 0.43), ('Algeria', 0.56), ('Russia', 1.81), ('Ethiopia', 1.55), ('Colombia', 0.65), ('Japan', 1.55), ('Thailand', 0.9), ('Spain', 0.6)}
